# %%
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data2 = pd.read_excel('MC_net.xlsx')
data2
# Out:
#                                         ID  \
# 0     0a1873d0-dd00-4e6e-8d66-7c7101f4a6ac
# 1     5ad9a9b5-9ef7-4cbd-956a-f0b57f7962e3
# 2     48149204-7734-4216-aba2-3701521484b2
# 3     df96cf3c-2405-45db-8f5a-54e5bb090e27
# 4     cc8cb7da-e9e6-42b9-8b13-42582abfe2a9
# ...                                    ...
# 5835  45e0fc4c-afd5-4790-aa91-fac6aa3296e5
# 5836  4b930fd3-9635-4c96-8409-a204dc0b028e
# 5837  bf4979e4-0691-4fdc-81ed-dda5e446a297
# 5838  c79d5118-3b59-4b48-9c89-6c38e32e900f
# 5839  df04e902-2975-4a5e-b4e4-250b16ae1fa4
#
#                              MeasurementID           ProductID BatchID  \
# 0     397fd968-6c09-412e-b01c-ee75946f6c3c  Siofor 1000, cores   10X22
# 1     397fd968-6c09-412e-b01c-ee75946f6c3c  Siofor 1000, cores   10X22
# 2     397fd968-6c09-412e-b01c-ee75946f6c3c  Siofor 1000, cores   10X22
# 3     397fd968-6c09-412e-b01c-ee75946f6c3c  Siofor 1000, cores   10X22
# 4     397fd968-6c09-412e-b01c-ee75946f6c3c  Siofor 1000, cores   10X22
# ...

# %%
data2.corr()
# Out:
#             Chamber  TabletNo    Weight  Thickness  Hardness
# Chamber    1.000000 -0.004271  0.031504  -0.107243  0.388751
# TabletNo  -0.004271  1.000000 -0.007127  -0.011966  0.234424
# Weight     0.031504 -0.007127  1.000000   0.574596  0.540175
# Thickness -0.107243 -0.011966  0.574596   1.000000  0.303999
# Hardness   0.388751  0.234424  0.540175   0.303999  1.000000

# %%
data2[['UserID', 'Hardness']].corr(method='kendall')
# Out:
#           Hardness
# Hardness       1.0

# %%
sns.heatmap(data2.corr(), annot=True)
# Out:
# <AxesSubplot:>
